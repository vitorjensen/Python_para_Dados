# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorjensen/Python_para_Dados/blob/main/Projetos/An%C3%A1lise%20Explorat%C3%B3ria%20de%20Carros/An%C3%A1lise_Explorat%C3%B3ria_de_Carros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Realizando a análise exploratória de Carros.

# %% [markdown]
# #### Importação de bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from pandas.core.arrays import categorical

# %%
df = pd.read_csv('/content/drive/MyDrive/automoveis_dataset.csv')

# %%
# Apresentando os dados através das 5 primeiras linhas
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %% [markdown]
# ##### Iniciando um tratamento de dados (Removendo colunas desnecessárias da base)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Reexibindo os dados (top)
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
# Exibindo os final do arquivo (bottom)
df.tail()
# Out:
#               car_name     brand   model  vehicle_age  km_driven seller_type  \
# 15406      Hyundai i10   Hyundai     i10            9      10723      Dealer
# 15407    Maruti Ertiga    Maruti  Ertiga            2      18000      Dealer
# 15408      Skoda Rapid     Skoda   Rapid            6      67000      Dealer
# 15409  Mahindra XUV500  Mahindra  XUV500            5    3800000      Dealer
# 15410       Honda City     Honda    City            2      13000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 15406    Petrol            Manual    19.81    1086      68.05      5
# 15407    Petrol            Manual    17.50    1373      91.10      7
# 15408    Diesel            Manual    21.14    1498     103.52      5
# 15409    Diesel            Manual    16.00    2179     140.00      7
# 15410    Petrol         Automatic    18.00    1497     117.60      5
#
#        selling_price
# 15406         250000
# 15407         925000
# ...

# %% [markdown]
# ##### Exibindo as colunas do arquivo

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %% [markdown]
# ##### Verificação dos Dados:
#       - Verificação dos Dados **nulos** e **Tipos de Dados** nas  colunas
#       - Verificação de Dados **duplicados**
#       - Verificação de Dados **únicos** por colunas

# %%
# Dados nulos e tipos de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
# Soma de Dados duplicados
df.duplicated().sum()
# Out:
# np.int64(167)

# %%
# Valores únicos em cada coluna
df.nunique()
# Out:
# car_name              121
# brand                  32
# model                 120
# vehicle_age            24
# km_driven            3688
# seller_type             3
# fuel_type               5
# transmission_type       2
# mileage               411
# engine                110
# max_power             342
# seats                   8
# selling_price        1086
# dtype: int64

# %% [markdown]
# ##### Resumo
#     - 15411 linhas e 13 colunas
#     - Não possui colunas nulas (Dados Faltantes)
#     - Tipos de colunas: 6 categóricas e 7 númericas
#     - Possui 167 linhas duplicadas

# %% [markdown]
# #####Segunda parte da Análise Exploratória:
#      - Explorando Dados
#      - Análise Univariada
#           - Gráfico de frequência
#      - Análise Múltivariada
#           - Correlação
#           - Média Bivariada

# %% [markdown]
# ##### Análise Exploratória

# %%
# Print de dados únicos em colunas específicas
print("Categoria em 'seller_type:'",end=" ")
print(df['seller_type'].unique())
print("\n")

print("Categorias em 'fuel_type:'", end=" ")
print(df['fuel_type'].unique())
print("\n")

print("Categorias em 'transmission_type:'", end=" ")
print(df['transmission_type'].unique())
print("\n")

print("Categorias em 'seats:'", end=" ")
print(df['seats'].unique())
print("\n")
# Out:
# Categoria em 'seller_type:' ['Individual' 'Dealer' 'Trustmark Dealer']
#
#
# Categorias em 'fuel_type:' ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
#
#
# Categorias em 'transmission_type:' ['Manual' 'Automatic']
#
#
# Categorias em 'seats:' [5 8 7 6 4 2 9 0]

# %% [markdown]
# ##### Avaliando Possíveis inconsistências de Dados

# %%
# Checagem das colunas e possíveis erros.
df[df['seats'] == 0]
# Out:
#            car_name   brand  model  vehicle_age  km_driven seller_type  \
# 3217     Honda City   Honda   City           18      40000  Individual
# 12619  Nissan Kicks  Nissan  Kicks            2      10000  Individual
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 3217     Petrol            Manual    13.00    1493     100.00      0
# 12619    Diesel            Manual    19.39    1461     108.49      0
#
#        selling_price
# 3217          115000
# 12619        1154000

# %%
# Reescrevendo os valores de 0 presentes nas linhas da coluna "seats" para 5
df.loc[df['seats'] == 0, 'seats'] = 5

# Ou se desejar remover as linhas contendo zero, use:
# df.drop(df[df['seats'] == 0].index, inplace=True)

# %%
df[df['seats'] == 0]
# Out:
# Empty DataFrame
# Columns: [car_name, brand, model, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
# Removendo a coluna redundante "mileage"
df.drop('mileage', axis=1, inplace=True)

# %%
# Renomear a coluna "Km_Driven" para "mileage"
df.rename(columns={'km_driven': 'MileAge'}, inplace=True)

# %%
df.tail(3)
# Out:
#               car_name     brand   model  vehicle_age  MileAge seller_type  \
# 15408      Skoda Rapid     Skoda   Rapid            6    67000      Dealer
# 15409  Mahindra XUV500  Mahindra  XUV500            5  3800000      Dealer
# 15410       Honda City     Honda    City            2    13000      Dealer
#
#       fuel_type transmission_type  engine  max_power  seats  selling_price
# 15408    Diesel            Manual    1498     103.52      5         425000
# 15409    Diesel            Manual    2179     140.00      7        1225000
# 15410    Petrol         Automatic    1497     117.60      5        1200000

# %% [markdown]
# ##### Avaliação dos atributos e classificação
#       - Verificando quais colunas são numéricas e categóricas.:

# %%
# Verificando quais colunas são numéricas e categóricas.

numeric_features = [feature for feature in df.columns
                    if df[feature].dtype != 'O']

categorical_features = [feature for feature in df.columns
                        if df[feature].dtype == 'O']

# Print das colunas
print(f"Temos {len(numeric_features)} numeric_features: {numeric_features}")
print(f"Temos {len(categorical_features)} categorical_features: {categorical_features}")
# Out:
# Temos 6 numeric_features: ['vehicle_age', 'MileAge', 'engine', 'max_power', 'seats', 'selling_price']
# Temos 6 categorical_features: ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %% [markdown]
# ##### Análise Univariada

# %%
warnings.filterwarnings('ignore')

# %%
#Variáveis Numéricas
plt.figure(figsize=(15,15))
plt.suptitle("Análise univariada de atributos numéricos", fontsize=20, fontweight='bold',alpha=0.8, y=1)

for i in range(len(numeric_features)):
  plt.subplot(5,3,i+1)
  sns.kdeplot(x=df[numeric_features[i]],shade=True,color='b')
  plt.xlabel(numeric_features[i])
  plt.tight_layout()

# %% [markdown]
# ##### Atributos Categóricos

# %%
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(15,15))
plt.suptitle("Análise univariada de atributos categóricos", fontsize=20, fontweight='bold',alpha=0.8, y=1)
cat1 = ['brand', 'seller_type', 'fuel_type', 'transmission_type']

for i in range(len(cat1)):
  plt.subplot(2,2,i+1)
  sns.countplot(x=df[cat1[i]])
  plt.xlabel(cat1[i])
  plt.xticks(rotation=45)
  plt.tight_layout()

# %% [markdown]
# #####Análise Multivariada
#   - Correlação

# %%
# Executando correlação linear de todos os atributos
df[numeric_features].corr()
# Out:
#                vehicle_age   MileAge    engine  max_power     seats  \
# vehicle_age       1.000000  0.333891  0.098965   0.005208  0.031938
# MileAge           0.333891  1.000000  0.192885   0.044421  0.192897
# engine            0.098965  0.192885  1.000000   0.807368  0.552778
# max_power         0.005208  0.044421  0.807368   1.000000  0.172812
# seats             0.031938  0.192897  0.552778   0.172812  1.000000
# selling_price    -0.241851 -0.080030  0.585844   0.750236  0.115231
#
#                selling_price
# vehicle_age        -0.241851
# MileAge            -0.080030
# engine              0.585844
# max_power           0.750236
# seats               0.115231
# selling_price       1.000000

# %%
# Visualizando as correlações
plt.figure(figsize=(15,10))
sns.heatmap(df[numeric_features].corr(), cmap='CMRmap', annot=True)
plt.show()
